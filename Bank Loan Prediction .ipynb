# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('C:/Users/Latika Bisht/Downloads/Bank_loan.csv')
df
# Out:
#       Loan_ID  Gender        Date Married Dependents     Education  \
# 0    LP001002    Male  01-01-2010      No          0      Graduate
# 1    LP001003    Male  02-02-2010     Yes          1      Graduate
# 2    LP001005    Male  03-03-2010     Yes          0      Graduate
# 3    LP001006    Male  01-01-2010     Yes          0  Not Graduate
# 4    LP001008    Male  02-02-2010      No          0      Graduate
# 5    LP001011    Male  03-03-2010     Yes          2      Graduate
# 6    LP001013    Male  01-01-2010     Yes          0  Not Graduate
# 7    LP001014    Male  02-02-2010     Yes         3+      Graduate
# 8    LP001018    Male  03-03-2010     Yes          2      Graduate
# 9    LP001020    Male  01-01-2010     Yes          1      Graduate
# 10   LP001024    Male  02-02-2010     Yes          2      Graduate
# 11   LP001027    Male  01-01-2010     Yes          2      Graduate
# 12   LP001028    Male  02-02-2010     Yes          2      Graduate
# ...

# %%
test= pd.read_csv('C:/Users/Latika Bisht/Documents/Bankloan_Test.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Date                 614 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 67.2+ KB

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Date                  object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df['Date']= pd.to_datetime(df.Date)
df.dtypes
# Out:
# Loan_ID                      object
# Gender                       object
# Date                 datetime64[ns]
# Married                      object
# Dependents                   object
# Education                    object
# Self_Employed                object
# ApplicantIncome               int64
# CoapplicantIncome           float64
# LoanAmount                  float64
# Loan_Amount_Term            float64
# Credit_History              float64
# Property_Area                object
# Loan_Status                  object
# dtype: object

# %%
df_length= len(df)
test_col=len(test.columns) #store total no. of columns in testing dataset

# %%
#understanding the various features of the dataset
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# For the non-numerical values (eg. property area,credit history etc) we can look at frequency distribution to understand if they
# make sense or not

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %% [markdown]
# Understanding distibution of numerical variable
# 1- Applicant Income
# 2- Loan Amount

# %%
#box plot to understand the distribution and look at the outlier
# %matplotlib inline
df['ApplicantIncome'].hist()

# %%
df.boxplot(column='ApplicantIncome')

# %%
df.shape
# Out:
# (614, 14)

# %%
test.shape
# Out:
# (194, 13)

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df['Loan_Status'].value_counts().plot.bar()
#The loan of 422(around 69%) people out of 614 was approved.

# %%
#loan status and credit history
pd.crosstab(df['Credit_History'],df['Loan_Status'],margins=True)
# Out:
# Loan_Status       N    Y  All
# Credit_History
# 0.0              82    7   89
# 1.0              97  378  475
# All             179  385  564

# %%
pd.crosstab(df['Credit_History'],df['Loan_Status']).apply(lambda r: r/r.sum(),axis=1)
#79.58% of the applicants whose loan got approved have credit history 1.
# Out:
# Loan_Status            N         Y
# Credit_History
# 0.0             0.921348  0.078652
# 1.0             0.204211  0.795789

# %%
pd.crosstab(df['Credit_History'],df['Gender']).apply(lambda r: r/r.sum(),axis=1)
# Out:
# Gender            Female      Male
# Credit_History
# 0.0             0.197674  0.802326
# 1.0             0.180258  0.819742

# %%
df['Self_Employed'].fillna('No',inplace=True) 
#replace missing values of self employed with more frequent value

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Male      0.813644
# Female    0.186356
# Name: Gender, dtype: float64

# %%
df['Gender'].value_counts(normalize=True).plot.bar(title= 'Gender')

# %%
df['Married'].value_counts(normalize=True).plot.bar(title= 'Married')

# %%
df['Self_Employed'].value_counts(normalize=True).plot.bar(title= 'Self_Employed')

# %% [markdown]
# Now let’s visualize the ordinal variables.

# %%
df['Dependents'].value_counts(normalize=True).plot.bar(title= 'Dependents')

# %%
df['Education'].value_counts(normalize=True).plot.bar(title= 'Education')

# %%
df['Property_Area'].value_counts(normalize=True).plot.bar(title= 'Property_Area')

# %% [markdown]
# Following inferences can be made from the above bar plots:
#
# Most of the applicants don’t have any dependents.
# Around 80% of the applicants are Graduate.
# Most of the applicants are from Semiurban area.

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Latika Bisht\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df['ApplicantIncome'].plot.box()

# %% [markdown]
# Categorical Independent Variable vs Target Variable

# %%
Gender=pd.crosstab(df['Gender'],df['Loan_Status'])

# %%
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
#feature engineering
df.mod['Totalincome']=df.mod['ApplicantIncome']+df.mod['CoapplicantIncome']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-b0230e0e383c> in <module>()
#       1 #feature engineering
# ----> 2 df.mod['Totalincome']=df.mod['ApplicantIncome']+df.mod['CoapplicantIncome']
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'
